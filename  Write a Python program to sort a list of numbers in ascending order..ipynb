# %% [markdown]
# # Write a Python program to sort a list of numbers in ascending order.

# %%
numbers = [int(i) for i in input("Enter numbers seperated by space : ").split()]
numbers.sort()
print(numbers)
# Out:
# Enter numbers seperated by space : 78 45 356 79 12 65 34 8 2 1
# [1, 2, 8, 12, 34, 45, 65, 78, 79, 356]
