# %% [markdown]
# # Write a Python program to check if a string is a palindrome.

# %%
s = input("Enter any string: ")
print("Given string is palindrome") if s== s[::-1] else print("Given string is not a palindrome")
