# %% [markdown]
# # Write a Python program to concatenate two strings.

# %%
str1 = input("Enter first string: ")
str2 = input("Enter the second string: ")

#concate_str = str1+str2
print("Strings after concatination :" , str1+" "+str2)
# Out:
# Enter first string: yush
# Enter the second string: ma
# Strings after concatination : yush ma
