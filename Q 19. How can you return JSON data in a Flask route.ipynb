# %%
from flask import Flask, jsonify
app = Flask(__name__)
@app.route('/data')

def data():
    
return jsonify({"name":'Yushma',"age":30})
if __name__ == '__main__':
    app.run()

# %%
import flask from Flask,jsonify
app = Flask(__name__)
@app.route("/data")

def data():
    return jsonify({"name":'yushma','age':30})
if __name__ =='__main__':
    app.run()

# %%
from flask import Flask,jsonify
app = Flask(__name__)
@app.route('/data')

def data():
    return jsonify({"name":'yushma','age':30})
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [23/Jun/2025 00:14:45] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [23/Jun/2025 00:14:58] "GET /data HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Jun/2025 00:14:58] "GET /favicon.ico HTTP/1.1" 404 -
