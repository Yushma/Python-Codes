# %%
import numpy as np
lst = [10, 20, 30, 40]

print(f"mean = {np.mean(lst)}")
print(f"median = {np.median(lst)}")
print(f"std = {np.std(lst)}")
# Out:
# mean = 25.0
# median = 25.0
# std = 11.180339887498949
