# %% [markdown]
# # Write a Python program to reverse a string.

# %%
s = input("Enter any string : ")
print("String after reversal: ",s[::-1])
# Out:
# Enter any string : yushma
# String after reversal:  amhsuy
