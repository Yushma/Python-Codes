# %% [markdown]
# # Create a nested list representing a 3x3 matrix and print the matrix. Access and print the element at the second row and third column.

# %%
matrix =[
    [1,2,3],
    [4,5,6],
    [7,8,9]
]
print(f"Given matrix: {matrix}")
print(f"second row and third column: {matrix[1][2]}")
# Out:
# Given matrix: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# second row and third column: 6

# %% [markdown]
# # Create a list of dictionaries where each dictionary represents a student with keys 'name' and 'score'. Sort the list of dictionaries by the 'score' in descending order and print the sorted list.

# %%
student_list =[
    {'name':'yushma', 'score':38},
    {'name':'prem','score':56},
    {'name':'Anu','score':98},
    {'name':'aaru','score':99}
]
reversed_list = sorted(student_list, key=lambda x: x["score"], reverse=True)
print(reversed_list)
# Out:
# [{'name': 'aaru', 'score': 99}, {'name': 'Anu', 'score': 98}, {'name': 'prem', 'score': 56}, {'name': 'yushma', 'score': 38}]
