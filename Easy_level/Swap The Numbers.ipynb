# %%
#Given two numbers a and b, you need to swap their values so a holds the value of b and b holds the value of a. Just write the code to swap values of a and b at the specified place.

# %%
def swap_nums(a,b):
    t = a
    a = b
    b = t
    return f"Value after swaping a = {a} and b = {b}"

a=10
b= 20
print(f"Value before swaping a= {a} and b={b}")
swap_nums(a,b)
# Out:
# Value before swaping a= 10 and b=20
# 'Value after swaping a = 20 and b = 10'
