# %%
#reading file
with open('file1.txt','r') as file:
    content = file.read()
    
print(content)
# Out:
# Hello world

# %%
#writting to file

with open('file1.txt','w') as file:
    file.write("Hello world")
